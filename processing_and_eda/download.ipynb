# %%
import prospectdataset as prospect

records = ['prospect', 'tmt', 'multi_ptm', 'tmt_ptm', 'test_ptm']

for record in records:
    prospect.download_dataset(record=record, save_directory=f'/mnt/c/Users/Florian/Desktop/Uni/MSc/FoPr/PROSPECT/downloaded_data/{record}')
# Out:
# ...
# Corresponding Zenodo URL is https://zenodo.org/record/6602020
# Collected URLs:  ['/records/6602020/files/Thermo_SRM_Pool_meta_data.parquet?download=1', '/records/6602020/files/TUM_aspn_meta_data.parquet?download=1', '/records/6602020/files/TUM_first_pool_meta_data.parquet?download=1', '/records/6602020/files/TUM_HLA2_meta_data.parquet?download=1', '/records/6602020/files/TUM_HLA_meta_data.parquet?download=1', '/records/6602020/files/TUM_isoform_meta_data.parquet?download=1', '/records/6602020/files/TUM_lysn_meta_data.parquet?download=1', '/records/6602020/files/TUM_missing_first_meta_data.parquet?download=1', '/records/6602020/files/TUM_proteo_TMT_meta_data.parquet?download=1', '/records/6602020/files/TUM_second_addon_meta_data.parquet?download=1', '/records/6602020/files/TUM_second_pool_meta_data.parquet?download=1', '/records/6602020/files/TUM_third_pool_meta_data.parquet?download=1']
# ...
